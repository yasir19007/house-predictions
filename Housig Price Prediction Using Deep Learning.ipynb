# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
 
# %matplotlib inline

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
df = pd.read_csv("../TensorFlow_FILES/DATA/kc_house_data.csv")
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10, 6))
sns.distplot(df['price'])
# Out:
# C:\Users\Yasir Qayyum\AppData\Local\Temp\ipykernel_2064\1203877565.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize=(12, 5))
sns.countplot(x=df['bedrooms'], hue=df['bedrooms'], palette='RdYlGn')
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
numeric_data = df.select_dtypes(include=[np.number])
numeric_data.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
# plt.figure(figsize=(13, 5))
# sns.heatmap(numeric_data, annot=True, cmap='coolwarm')
# plt.show()

# %%
plt.figure(figsize=(13, 5))
sns.scatterplot(x='price', y='sqft_living', data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(13, 5))
sns.boxplot(x='bedrooms', y='price', data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 5))
sns.scatterplot(x=df['price'], y=df['long'], data=df)
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(13, 5))
sns.scatterplot(x=df['price'], y=df['lat'], data=df)
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(13, 6))
sns.scatterplot(x=df['long'], y=df['lat'], hue='price', data=df)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
#  we are not getting the proper gradient just because of the few outliers
#  outliers are those prices which are extremly high and they are just few prices

df.sort_values('price', ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
#  drop the first 1% of data, because it is the extremly high values

len(df) * 0.01
# Out:
# 215.97

# %%
non_top_1_perc = df.sort_values('price', ascending=False).iloc[216:]

non_top_1_perc
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='long', y='lat', data=non_top_1_perc, edgecolor=None, 
                alpha=0.2, palette='RdYlGn', hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['waterfront'], y=df['price'], data=df, palette='RdYlGn')
# Out:
# C:\Users\Yasir Qayyum\AppData\Local\Temp\ipykernel_2064\2108591988.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['waterfront'], y=df['price'], data=df, palette='RdYlGn')
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df = df.drop('id', axis=1)

df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %% [markdown]
# ## **Feature Engineering From Date Column**

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
# Date is a string object lets change it to date time object

df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
#  Extract the year and Month column from date time

df['year']  = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date:date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(x='month', y='price', data=df, palette='RdYlGn')
# Out:
# C:\Users\Yasir Qayyum\AppData\Local\Temp\ipykernel_2064\2112030733.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='month', y='price', data=df, palette='RdYlGn')
# <Axes: xlabel='month', ylabel='price'>

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(x='year', y='price', data=df, palette='RdYlGn')
# Out:
# C:\Users\Yasir Qayyum\AppData\Local\Temp\ipykernel_2064\837776742.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='year', y='price', data=df, palette='RdYlGn')
# <Axes: xlabel='year', ylabel='price'>

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15, 7))
df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
plt.figure(figsize=(15, 7))
df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
df = df.drop('date', axis=1)
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df = df.drop('zipcode', axis=1)
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
df['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: count, Length: 306, dtype: int64

# %% [markdown]
# # **Train Test Split**

# %%
X = df.drop('price', axis=1)
y= df['price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
X_test.shape
# Out:
# (6480, 19)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# X = scaler.fit_transform(X)
# X

X_train
# Out:
# array([[0.3       , 0.08      , 0.19855222, ..., 0.00657863, 0.        ,
#         0.72727273],
#        [0.2       , 0.28      , 0.1302999 , ..., 0.00288289, 0.        ,
#         0.45454545],
#        [0.3       , 0.48      , 0.25646329, ..., 0.00588823, 1.        ,
#         0.36363636],
#        ...,
#        [0.1       , 0.2       , 0.14788004, ..., 0.00786147, 1.        ,
#         0.27272727],
#        [0.2       , 0.24      , 0.11685626, ..., 0.01557367, 1.        ,
#         0.27272727],
#        [0.1       , 0.08      , 0.08169597, ..., 0.00515118, 1.        ,
#         0.        ]])

# %%
X_test = scaler.transform(X_test)
X_test
# Out:
# array([[0.1       , 0.08      , 0.04239917, ..., 0.00887725, 0.        ,
#         0.63636364],
#        [0.3       , 0.36      , 0.17269907, ..., 0.00993734, 0.        ,
#         0.81818182],
#        [0.2       , 0.24      , 0.12512927, ..., 0.00547073, 0.        ,
#         0.90909091],
#        ...,
#        [0.1       , 0.08      , 0.05584281, ..., 0.00506255, 0.        ,
#         1.        ],
#        [0.3       , 0.2       , 0.22233713, ..., 0.00774485, 1.        ,
#         0.09090909],
#        [0.3       , 0.32      , 0.27611169, ..., 0.0196531 , 0.        ,
#         0.45454545]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
#  the shape of the input data is 19 inputs or features thats why we have taken 19
#  neurons in the first layer

model = Sequential()

model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
# validation data is used to see the LOSE using test data after each epoch during training on the training data
# Validation data : After each epoch of training on the training data, the model will run the test data to check the loss on our data

model.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), batch_size=132, epochs=400)
# Out:
# Epoch 1/400
# 115/115 [==============================] - 3s 5ms/step - loss: 430231977984.0000 - val_loss: 418884124672.0000
# Epoch 2/400
# 115/115 [==============================] - 0s 4ms/step - loss: 429009862656.0000 - val_loss: 414814339072.0000
# Epoch 3/400
# 115/115 [==============================] - 0s 3ms/step - loss: 413057810432.0000 - val_loss: 378203078656.0000
# Epoch 4/400
# 115/115 [==============================] - 0s 3ms/step - loss: 333093601280.0000 - val_loss: 249337937920.0000
# Epoch 5/400
# 115/115 [==============================] - 0s 3ms/step - loss: 177213161472.0000 - val_loss: 110680662016.0000
# Epoch 6/400
# 115/115 [==============================] - 0s 4ms/step - loss: 102831652864.0000 - val_loss: 95314845696.0000
# Epoch 7/400
# 115/115 [==============================] - 0s 3ms/step - loss: 97607491584.0000 - val_loss: 93763264512.0000
# Epoch 8/400
# ...

# %% [markdown]
# ### **Comparing Training Loss vs Validation Loss**

# %%
losses = pd.DataFrame(model.history.history)

losses
# Out:
#              loss      val_loss
# 0    4.302320e+11  4.188841e+11
# 1    4.290099e+11  4.148143e+11
# 2    4.130578e+11  3.782031e+11
# 3    3.330936e+11  2.493379e+11
# 4    1.772132e+11  1.106807e+11
# ..            ...           ...
# 395  2.938595e+10  2.712685e+10
# 396  2.936790e+10  2.702646e+10
# 397  2.933797e+10  2.703003e+10
# 398  2.934351e+10  2.703037e+10
# 399  2.932907e+10  2.704638e+10
#
# [400 rows x 2 columns]

# %%
losses.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
model_prediction = model.predict(X_test)
# Out:
# 203/203 [==============================] - 1s 2ms/step

# %%
np.sqrt(mean_squared_error(y_test, model_prediction))
# Out:
# 164457.84599274918

# %%
mean_absolute_error(y_test, model_prediction)
# Out:
# 102751.88325978974

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test, model_prediction)
# Out:
# 0.7963534191272713

# %%
plt.figure(figsize=(12, 6))

plt.scatter(y_test, model_prediction)

# Perfect straight line
plt.plot(y_test, y_test, 'r')

# %% [markdown]
# ### **Predict on a brand new data**

# %%
new_house = df.drop('price', axis=1).iloc[1]
new_house
# Out:
# bedrooms            3.000
# bathrooms           2.250
# sqft_living      2570.000
# sqft_lot         7242.000
# floors              2.000
# waterfront          0.000
# view                0.000
# condition           3.000
# grade               7.000
# sqft_above       2170.000
# sqft_basement     400.000
# yr_built         1951.000
# yr_renovated     1991.000
# lat                47.721
# long             -122.319
# sqft_living15    1690.000
# sqft_lot15       7639.000
# year             2014.000
# month              12.000
# Name: 1, dtype: float64

# %%
new_house = scaler.transform(new_house.values.reshape(-1, 19))
new_house
# Out:
# c:\softwares\python 3.11.5\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# array([[0.2       , 0.28      , 0.22750776, 0.00407187, 0.4       ,
#         0.        , 0.        , 0.5       , 0.4       , 0.23968043,
#         0.08298755, 0.44347826, 0.98808933, 0.90895931, 0.16611296,
#         0.22216486, 0.0081402 , 0.        , 1.        ]])

# %%
model.predict(new_house)
# Out:
# 1/1 [==============================] - 0s 55ms/step
# array([[645417.8]], dtype=float32)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...
